# %% [markdown]
# <a href="https://colab.research.google.com/github/carolaalmeidas/data-portfolio-ana-carolina/blob/taxi-nyc-analysis/Download1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')
df.head()

# %%
df.info()
df.describe()
df.isnull().sum()

# %%
df['pickup'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['dropoff'] = pd.to_datetime(df['tpep_dropoff_datetime'])

df['trip_duration_min'] = (df['dropoff'] - df['pickup']).dt.total_seconds() / 60

df['fare_per_mile'] = df['fare_amount'] / df['trip_distance']

# %%
df['trip_distance'].mean()
df['tip_amount'].mean()
df['trip_duration_min'].mean()
