# %% [markdown]
# <a href="https://colab.research.google.com/github/carolaalmeidas/data-portfolio-ana-carolina/blob/taxi-nyc-analysis/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')
df.head()
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
df['pickup'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['dropoff'] = pd.to_datetime(df['tpep_dropoff_datetime'])

df['trip_duration_min'] = (df['dropoff'] - df['pickup']).dt.total_seconds() / 60

df['fare_per_mile'] = df['fare_amount'] / df['trip_distance']

# %%
df['trip_distance'].mean()
df['tip_amount'].mean()
df['trip_duration_min'].mean()
# Out:
# np.float64(17.013776671512694)

# %% [markdown]
# ## 📊 Principais Insights
#
# - A distância média das viagens é aproximadamente **X milhas**, indicando que a maioria das corridas é relativamente curta.
#
# - A duração média das viagens é cerca de **X minutos**, sugerindo uma alta frequência de deslocamentos rápidos em áreas urbanas.
#
# - O valor médio das gorjetas reflete o comportamento dos usuários, podendo variar de acordo com o tipo de pagamento e a duração da viagem.
#
# - Esses padrões indicam oportunidades estratégicas, como a otimização de preços e a melhor distribuição de motoristas em regiões de maior demanda.

# %% [markdown]
# A distância média das viagens é aproximadamente **2.8 milhas**

# %%
df['trip_distance'].mean()
df['trip_duration_min'].mean()
df['tip_amount'].mean()
# Out:
# np.float64(1.8357813119520685)
